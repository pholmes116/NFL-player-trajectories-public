# %% [markdown]
# # Loading Model and Testing

# %%
import sys
import os
import tqdm
import tensorflow as tf
import numpy as np
import pandas as pd

from tqdm import tqdm
from pathlib import Path
from importlib import reload

from Base_transformer import TransformerPredictor 
from play_loader import load_play

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))
import custom_visualizer; reload(custom_visualizer)
# Out:
# 2025-05-02 18:29:55.817611: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-02 18:29:56.238762: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746203396.362642 1044278 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746203396.402789 1044278 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746203396.733013 1044278 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746203396.733161 1044278 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746203396.733168 1044278 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746203396.733170 1044278 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-02 18:29:56.769740: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <module 'custom_visualizer' from '/home/sebas/ml/Deep Learning/2025-projects-shallowlearning/code/custom_visualizer.py'>

# %%
print("Visible GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# Visible GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
cfg_big = dict(
    num_feats = 46,
    max_len   = 100,
    d_model   = 192,
    n_heads   = 8,       
    n_layers  = 12,      
    d_ff      = 768,     
    dropout   = 0.20,    
)
WEIGHT_FOLDER = Path("../../weights_big_transformer")
TRAIN_MODEL   = False         # set True to launch training

# %%
EPOCHS = 2000
PATIENCE = 20

if TRAIN_MODEL:
    WEIGHT_FOLDER.mkdir(parents=True, exist_ok=True)
    cmd = (
        "python Base_transformer_trainer.py "
        "--data ../../processed_data/transformer_dataset_9 "
        f"--weights_dir {WEIGHT_FOLDER} "
        "--batch 256 "
        f"--epochs {EPOCHS} "
        f"--patience {PATIENCE} "
        f"--num_feats {cfg_big['num_feats']} "
        f"--max_len {cfg_big['max_len']} "
        f"--d_model  {cfg_big['d_model']} "
        f"--n_heads  {cfg_big['n_heads']} "
        f"--n_layers {cfg_big['n_layers']} "
        f"--d_ff     {cfg_big['d_ff']} "
        f"--dropout  {cfg_big['dropout']} "
        "--mixed_precision mixed_float16 "
        "--plot "
        "--evaluate "
    )
    print("\n⚙️ Launching training:\n", cmd)
    os.system(cmd)

# %%
#WEIGHT_PATTERN = "weights/epoch_{:03d}-val{:.4f}.weights.h5"

WEIGHT_FILE = f"{WEIGHT_FOLDER}/best.weights.h5"   # adjust as needed

model = TransformerPredictor(dtype_policy="mixed_float16", **cfg_big)  # or omit arg for fp32
#model = TransformerPredictor()
model.load_weights(WEIGHT_FILE)

model.summary()  # sanity-check layer names/shapes match the notebook
# Out:
# I0000 00:00:1746203406.749009 1044278 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9511 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "NFL_Frame_Predictor"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ sequence            │ (None, 100, 46)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cast (Cast)         │ (None, 100, 46)   │          0 │ sequence[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ proj_xy (Dense)     │ (None, 100, 192)  │      9,024 │ cast[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cast_1 (Cast)       │ (None, 100, 46)   │          0 │ sequence[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pos_enc             │ (None, 100, 192)  │     19,200 │ proj_xy[0][0]     │
# │ (PositionalEncodin… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pad_mask            │ (None, 1, 1, 100) │          0 │ cast_1[0][0]      │
# │ (PaddingMask)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional          │ (None, 100, 192)  │    444,864 │ pos_enc[0][0],    │
# │ (Functional)        │                   │            │ pad_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_1        │ (None, 100, 192)  │    444,864 │ functional[0][0], │
# │ (Functional)        │                   │            │ pad_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_2        │ (None, 100, 192)  │    444,864 │ functional_1[0][… │
# │ (Functional)        │                   │            │ pad_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_3        │ (None, 100, 192)  │    444,864 │ functional_2[0][… │
# │ (Functional)        │                   │            │ pad_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_4        │ (None, 100, 192)  │    444,864 │ functional_3[0][… │
# │ (Functional)        │                   │            │ pad_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_5        │ (None, 100, 192)  │    444,864 │ functional_4[0][… │
# │ (Functional)        │                   │            │ pad_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_6        │ (None, 100, 192)  │    444,864 │ functional_5[0][… │
# │ (Functional)        │                   │            │ pad_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_7        │ (None, 100, 192)  │    444,864 │ functional_6[0][… │
# │ (Functional)        │                   │            │ pad_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_8        │ (None, 100, 192)  │    444,864 │ functional_7[0][… │
# │ (Functional)        │                   │            │ pad_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_9        │ (None, 100, 192)  │    444,864 │ functional_8[0][… │
# │ (Functional)        │                   │            │ pad_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_10       │ (None, 100, 192)  │    444,864 │ functional_9[0][… │
# │ (Functional)        │                   │            │ pad_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_11       │ (None, 100, 192)  │    444,864 │ functional_10[0]… │
# │ (Functional)        │                   │            │ pad_mask[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_last_hidden  │ (None, 192)       │          0 │ functional_11[0]… │
# │ (Lambda)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cast_26 (Cast)      │ (None, 192)       │          0 │ lambda_last_hidd… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pred_xy (Dense)     │ (None, 46)        │      8,878 │ cast_26[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,375,470 (20.51 MB)
#  Trainable params: 5,375,470 (20.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
BATCH_SIZE   = 8
CNTX_SIZE = 80   
N_STEPS = 10

                 # < MAX_LEN just for demo
dummy_seq_batch = tf.random.uniform([BATCH_SIZE, CNTX_SIZE, 46])
dummy_seq = tf.random.uniform([CNTX_SIZE, 46])

y_next = model.predict_next(dummy_seq)  # (46,)
print("Next-frame prediction shape:", y_next.shape) 

y_next_batch = model.predict_next(dummy_seq_batch)      # (8, 46)
print("Next-frame prediction shape:", y_next_batch.shape)

N_FUTRE = 10

y_future = model.predict_autoregressive(dummy_seq, n_steps=N_STEPS)  # (10, 46)
print("Autoregressive rollout shape:", y_future.shape)

y_future_batch = model.predict_autoregressive(dummy_seq_batch, n_steps=N_STEPS)  # (8, 10, 46)
print("Autoregressive rollout shape:", y_future_batch.shape)
# Out:
# 2025-05-02 18:30:10.931696: E tensorflow/core/util/util.cc:131] oneDNN supports DT_HALF only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# Next-frame prediction shape: (46,)
# Next-frame prediction shape: (8, 46)
# Autoregressive rollout shape: (10, 46)
# Autoregressive rollout shape: (8, 10, 46)

# %% [markdown]
# # Visalizing

# %% [markdown]
# ## Test set context, Random start

# %%
DATASET_PATH = "../../processed_data/transformer_dataset_9"

def filter_split(split_num):
    def _filter(meta, x, y):
        return tf.equal(meta[2], split_num)
    return _filter

def drop_meta(meta, x, y):
    return x, y

raw_ds = tf.data.Dataset.load(DATASET_PATH)

test_ds  = (raw_ds
            .filter(filter_split(2))
            .shuffle(4096)
            .batch(1)
            .prefetch(tf.data.AUTOTUNE))

# %%
play = next(iter(test_ds))            # a single batch (meta, x, y)

meta, x_ctx, y_next = play            # x_ctx: (1,100,46)"""

N_STEPS = 50
y_future = model.predict_autoregressive(x_ctx, n_steps=N_STEPS)  # (1,100,46)

print("context shape:", x_ctx.shape)
print("future   shape:", y_future.shape)

_ = custom_visualizer.plot_trajectories(
        sequence=x_ctx[0],                 # solid lines:   100-frame context
        offense='all', defense='all', include_ball=True,
        ground_truth_seq=None,
        pred_seq=y_future       # dashed lines: model rollout
        )
# Out:
# context shape: (1, 100, 46)
# future   shape: (1, 50, 46)

# %% [markdown]
# ## Predict post snap with presnap context

# %%
from play_loader import load_play

# %%
game_indexer = pd.read_parquet("../../processed_data/train_test_val.parquet")

df = pd.read_parquet("../../processed_data/model_input_2.parquet")
df = df[['gameId', 'playId']].copy()

game_indexer_test = df.merge(game_indexer, how="left", on=["gameId", "playId"])

#game_indexer_test = game_indexer.loc[game_indexer['split'] == "test", ['gameId', 'playId']].copy()

# %%
# Filter to test rows and pick one at random
N_STEPS = 40

#################### Samples a random play from the test set #####################
row = game_indexer_test.sample(n=1)  # pick a random row from the test set

#gameId = row['gameId'].iloc[0] # Replace with specific gameId if needed
#playId = row['playId'].iloc[0] # Replace with specific gameId if needed

gameId = 2022091110
playId = 3331

###################################################################################

print(f"Selected gameId = {gameId}, playId = {playId}")

context_seq, gt_future = load_play(
    parquet_path="../../processed_data/model_input_9.parquet",
    game_id=gameId,
    play_id=playId,
    ctx_len=100,
    n_future=N_STEPS,
)

pred = model.predict_autoregressive(context_seq, n_steps=N_STEPS)

_ = custom_visualizer.plot_trajectories(
        sequence=context_seq[0],
        ground_truth_seq=gt_future,
        pred_seq=pred,
        offense='all', defense='all', include_ball=True)
# Out:
# Selected gameId = 2022091110, playId = 3331

# %%
pred[:,:, 44:]*120
# Out:
# <tf.Tensor: shape=(1, 30, 2), dtype=float32, numpy=
# array([[[79.3062  , 26.68524 ],
#         [79.578125, 26.616486],
#         [79.94583 , 26.559183],
#         [80.22168 , 26.478624],
#         [80.55312 , 26.385323],
#         [80.94697 , 26.262663],
#         [81.291855, 26.130674],
#         [81.65193 , 26.01948 ],
#         [82.03019 , 25.863533],
#         [82.38008 , 25.69998 ],
#         [82.756775, 25.498932],
#         [83.10826 , 25.262053],
#         [83.516266, 25.053242],
#         [83.98503 , 24.808752],
#         [84.37146 , 24.549372],
#         [84.83277 , 24.280611],
#         [85.30663 , 24.01759 ],
#         [85.79327 , 23.68732 ],
#         [86.26424 , 23.393845],
#         [86.73723 , 23.069933],
#         [87.2198  , 22.694967],
#         [87.768   , 22.343315],
#         [88.2698  , 21.93528 ],
#         [88.748886, 21.516365],
#         [89.3005  , 21.115772],
#         [89.825485, 20.68571 ],
#         [90.33754 , 20.230133],
#         [90.89458 , 19.715935],
#         [91.39216 , 19.203232],
#         [91.9285  , 18.669563]]], dtype=float32)>

# %%
N_STEPS = 30

row = (
    game_indexer
    .loc[game_indexer['split'] == "test", ['gameId', 'playId']]
    .sample(n=1) 
)

context_seq, gt_future = load_play(
    parquet_path="../../processed_data/model_input_9.parquet",
    game_id=gameId,
    play_id=playId,
    ctx_len=100,
    n_future=N_STEPS,
)

pred = model.predict_autoregressive(context_seq, n_steps=N_STEPS)

_ = custom_visualizer.plot_trajectories(
        sequence=context_seq[0],
        ground_truth_seq=None,
        pred_seq=pred,
        offense='all', defense='all', include_ball=True)

# %% [markdown]
# ## Evaluating Model performance with 40 rollout prediction

# %%
df = pd.read_parquet("../../processed_data/model_input_2.parquet")
df = df[['gameId', 'playId']].copy()
game_indexer = df.merge(game_indexer, how="left", on=["gameId", "playId"])
game_indexer_test = game_indexer.loc[game_indexer['split'] == "test", ['gameId', 'playId']].copy()

# %%
"""N_STEPS = 40
N_EXAMPLES = 100

# Will hold an (n_plays, N_STEPS) array of L2 errors
all_errors = []

# Loop over every play in the test set
for gameId, playId in tqdm(game_indexer_test.values[:N_EXAMPLES], desc="Evaluating plays"):
    # load context + ground truth future
    context_seq, gt_future = load_play(
        parquet_path="../../processed_data/model_input_2.parquet",
        game_id=gameId,
        play_id=playId,
        ctx_len=100,
        n_future=N_STEPS,
    )

    # Skip if sequence is empty
    if context_seq is None or gt_future is None:
        continue
    # Skip if sequence is all zeros
    if np.all(context_seq == 0) or np.all(gt_future == 0):
        continue
    # Skip if gt_future is less than N_STEPS
    if gt_future.shape[1] < N_STEPS:
        continue

    # Calculate length of the sequence to be predicted
    seq_len = gt_future.shape[1]  # (100, 46)
    
    # autoregressive prediction
    pred = model.predict_autoregressive(context_seq, n_steps=N_STEPS)
    
    # ground-truth for those same steps
    gt = gt_future[0]                                       # (N_STEPS, 46)
    
    # per-frame Euclidean distance (add small eps for stability)
    dists = np.sqrt(np.sum((pred - gt)**2, axis=-1) + 1e-6)  # (N_STEPS,)
    
    all_errors.append(dists)

all_errors = np.stack(all_errors)  # shape = (n_plays, N_STEPS)

# mean error at each future step
mean_error_per_step = all_errors.mean(axis=0)  # (N_STEPS,)

# overall mean error (averaged across all plays & steps)
overall_mean_error = all_errors.mean()

print(f"\nOverall mean Euclidean error (all plays & steps): {overall_mean_error:.4f}")
print(f"\nMultiplied by 120: {overall_mean_error * 120:.4f}")"""
# Out:
# Evaluating plays:   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating plays:   0%|          | 0/100 [00:11<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 32
#      29 seq_len = gt_future.shape[1]  # (100, 46)
#      31 # autoregressive prediction
# ---> 32 pred = model.predict_autoregressive(context_seq, n_steps=N_STEPS)
#      34 # ground-truth for those same steps
#      35 gt = gt_future[0]                                       # (N_STEPS, 46)
#
# File ~/ml/Deep Learning/2025-projects-shallowlearning/code/Models/Base_transformer.py:188, in TransformerPredictor.predict_autoregressive(self, seq, n_steps, training)
#     184 def predict_autoregressive(
#     185     self, seq: tf.Tensor, n_steps: int, training: bool = False
#     186 ) -> tf.Tensor:
#     187     """Alias for `predict(seq, n_steps)`."""
# --> 188     return self.predict(seq, n_steps=n_steps, training=training)
#
# File ~/ml/Deep Learning/2025-projects-shallowlearning/code/Models/Base_transformer.py:168, in TransformerPredictor.predict(self, seq, n_steps, training)
#     166 preds: list[tf.Tensor] = []
#     167 for _ in range(n_steps):
# --> 168     y = self.model(seq, training=training)            # (B,46)
#     169     preds.append(y)
#     170     y_exp = tf.expand_dims(y, 1)                     # (B,1,46)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/layers/layer.py:907, in Layer.__call__(self, *args, **kwargs)
#     905 if new_scope is not None:
#     906     with new_scope:
# --> 907         outputs = super().__call__(*args, **kwargs)
#     908 else:
#     909     outputs = super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/ops/operation.py:52, in Operation.__call__(self, *args, **kwargs)
#      47                 call_fn = self.call
#      48     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      49         call_fn,
#      50         object_name=(f"{self.__class__.__name__}.call()"),
#      51     )
# ---> 52     return call_fn(*args, **kwargs)
#      54 # Plain flow.
#      55 if any_symbolic_tensors(args, kwargs):
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/models/functional.py:183, in Functional.call(self, inputs, training, mask)
#     181         if mask is not None:
#     182             backend.set_keras_mask(x, mask)
# --> 183 outputs = self._run_through_graph(
#     184     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     185 )
#     186 return unpack_singleton(outputs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/ops/function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/models/functional.py:643, in operation_fn.<locals>.call(*args, **kwargs)
#     637 if (
#     638     hasattr(operation, "_call_has_training_arg")
#     639     and operation._call_has_training_arg
#     640     and training is not None
#     641 ):
#     642     kwargs["training"] = training
# --> 643 return operation(*args, **kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/layers/layer.py:909, in Layer.__call__(self, *args, **kwargs)
#     907         outputs = super().__call__(*args, **kwargs)
#     908 else:
# --> 909     outputs = super().__call__(*args, **kwargs)
#     910 # Change the layout for the layer output if needed.
#     911 # This is useful for relayout intermediate tensor in the model
#     912 # to achieve the optimal performance.
#     913 distribution = distribution_lib.distribution()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/ops/operation.py:52, in Operation.__call__(self, *args, **kwargs)
#      47                 call_fn = self.call
#      48     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      49         call_fn,
#      50         object_name=(f"{self.__class__.__name__}.call()"),
#      51     )
# ---> 52     return call_fn(*args, **kwargs)
#      54 # Plain flow.
#      55 if any_symbolic_tensors(args, kwargs):
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/models/functional.py:183, in Functional.call(self, inputs, training, mask)
#     181         if mask is not None:
#     182             backend.set_keras_mask(x, mask)
# --> 183 outputs = self._run_through_graph(
#     184     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     185 )
#     186 return unpack_singleton(outputs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/ops/function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/models/functional.py:643, in operation_fn.<locals>.call(*args, **kwargs)
#     637 if (
#     638     hasattr(operation, "_call_has_training_arg")
#     639     and operation._call_has_training_arg
#     640     and training is not None
#     641 ):
#     642     kwargs["training"] = training
# --> 643 return operation(*args, **kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/layers/layer.py:907, in Layer.__call__(self, *args, **kwargs)
#     905 if new_scope is not None:
#     906     with new_scope:
# --> 907         outputs = super().__call__(*args, **kwargs)
#     908 else:
#     909     outputs = super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/ops/operation.py:52, in Operation.__call__(self, *args, **kwargs)
#      47                 call_fn = self.call
#      48     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      49         call_fn,
#      50         object_name=(f"{self.__class__.__name__}.call()"),
#      51     )
# ---> 52     return call_fn(*args, **kwargs)
#      54 # Plain flow.
#      55 if any_symbolic_tensors(args, kwargs):
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/layers/normalization/layer_normalization.py:222, in LayerNormalization.call(self, inputs)
#     219 else:
#     220     # Calculate the mean & variance along self.axis (layer activations).
#     221     mean, variance = ops.moments(inputs, axes=self.axis, keepdims=True)
# --> 222     gamma, beta = _broadcast(self.gamma), _broadcast(self.beta)
#     224     inv = ops.rsqrt(variance + self.epsilon)
#     225     if gamma is not None:
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/layers/normalization/layer_normalization.py:201, in LayerNormalization.call.<locals>._broadcast(v)
#     195 def _broadcast(v):
#     196     if (
#     197         v is not None
#     198         and len(v.shape) != ndims
#     199         and self.axis != [ndims - 1]
#     200     ):
# --> 201         return ops.reshape(v, broadcast_shape)
#     202     return v
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/ops/numpy.py:4937, in reshape(x, newshape)
#    4935 if any_symbolic_tensors((x,)):
#    4936     return Reshape(newshape).symbolic_call(x)
# -> 4937 return backend.numpy.reshape(x, newshape)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/backend/tensorflow/numpy.py:2024, in reshape(x, newshape)
#    2022     output.set_shape(output_shape)
#    2023     return output
# -> 2024 return tf.reshape(x, newshape)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/weak_tensor_ops.py:88, in weak_tensor_unary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#      86 def wrapper(*args, **kwargs):
#      87   if not ops.is_auto_dtype_conversion_enabled():
# ---> 88     return op(*args, **kwargs)
#      89   bound_arguments = signature.bind(*args, **kwargs)
#      90   bound_arguments.apply_defaults()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:199, in reshape(tensor, shape, name)
#      63 @tf_export("reshape", v1=["reshape", "manip.reshape"])
#      64 @dispatch.add_dispatch_support
#      65 def reshape(tensor, shape, name=None):  # pylint: disable=redefined-outer-name
#      66   r"""Reshapes a tensor.
#      67
#      68   Given `tensor`, this operation returns a new `tf.Tensor` that has the same
#    (...)
#     197     A `Tensor`. Has the same type as `tensor`.
#     198   """
# --> 199   result = gen_array_ops.reshape(tensor, shape, name)
#     200   shape_util.maybe_set_static_shape(result, shape)
#     201   return result
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/gen_array_ops.py:8795, in reshape(tensor, shape, name)
#    8793   pass
#    8794 try:
# -> 8795   return reshape_eager_fallback(
#    8796       tensor, shape, name=name, ctx=_ctx)
#    8797 except _core._SymbolicException:
#    8798   pass  # Add nodes to the TensorFlow graph.
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/gen_array_ops.py:8816, in reshape_eager_fallback(tensor, shape, name, ctx)
#    8815 def reshape_eager_fallback(tensor: Annotated[Any, TV_Reshape_T], shape: Annotated[Any, TV_Reshape_Tshape], name, ctx) -> Annotated[Any, TV_Reshape_T]:
# -> 8816   _attr_T, (tensor,) = _execute.args_to_matching_eager([tensor], ctx, [])
#    8817   _attr_Tshape, (shape,) = _execute.args_to_matching_eager([shape], ctx, [_dtypes.int32, _dtypes.int64, ], _dtypes.int32)
#    8818   _inputs_flat = [tensor, shape]
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:259, in args_to_matching_eager(***failed resolving arguments***)
#     256     tensor = None
#     258 if tensor is None:
# --> 259   tensor = tensor_conversion_registry.convert(
#     260       t, dtype, preferred_dtype=default_dtype
#     261   )
#     263 ret.append(tensor)
#     264 if dtype is None:
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/backend/tensorflow/core.py:80, in Variable.__tf_tensor__(self, dtype, name)
#      79 def __tf_tensor__(self, dtype=None, name=None):
# ---> 80     return tf.convert_to_tensor(self.value, dtype=dtype, name=name)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion.py:161, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#      96 @tf_export.tf_export("convert_to_tensor", v1=[])
#      97 @dispatch.add_dispatch_support
#      98 def convert_to_tensor_v2_with_dispatch(
#      99     value, dtype=None, dtype_hint=None, name=None
#     100 ) -> tensor_lib.Tensor:
#     101   """Converts the given `value` to a `Tensor`.
#     102
#     103   This function converts Python objects of various types to `Tensor`
#    (...)
#     159     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#     160   """
# --> 161   return convert_to_tensor_v2(
#     162       value, dtype=dtype, dtype_hint=dtype_hint, name=name
#     163   )
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion.py:171, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#     169 """Converts the given `value` to a `Tensor`."""
#     170 # preferred_dtype = preferred_dtype or dtype_hint
# --> 171 return tensor_conversion_registry.convert(
#     172     value, dtype, name, preferred_dtype=dtype_hint
#     173 )
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:2378, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2377 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2378   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:1624, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1622   return self.read_value().op.inputs[0]
#    1623 else:
# -> 1624   return self.value()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:658, in BaseResourceVariable.value(self)
#     656   return self._cached_value
#     657 with ops.colocate_with(None, ignore_existing=True):
# --> 658   return self._read_variable_op()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:843, in BaseResourceVariable._read_variable_op(self, no_copy)
#     841       result = read_and_set_handle(no_copy)
#     842 else:
# --> 843   result = read_and_set_handle(no_copy)
#     845 if not context.executing_eagerly():
#     846   # Note that if a control flow context is active the input of the read op
#     847   # might not actually be the handle. This line bypasses it.
#     848   record.record_operation(
#     849       "ReadVariableOp", [result], [self.handle],
#     850       backward_function=lambda x: [x],
#     851       forward_function=lambda x: [x])
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:833, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     831 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     832   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 833 result = gen_resource_variable_ops.read_variable_op(
#     834     self.handle, self._dtype)
#     835 _maybe_set_handle_data(self._dtype, self.handle, result)
#     836 return result
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/gen_resource_variable_ops.py:534, in read_variable_op(resource, dtype, name)
#     532 if tld.is_eager:
#     533   try:
# --> 534     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     535       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     536     return _result
#     537   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
